# %%
import pandas as pd

# %%
energie = pd.read_csv("eco2mix.csv", sep = ";")
energie.head()
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_15344\3879831466.py:1: DtypeWarning: Columns (0: Eolien (MW)) have mixed types. Specify dtype option on import or set low_memory=False.
#   energie = pd.read_csv("eco2mix.csv", sep = ";")
#    Code INSEE région           Région               Nature        Date  Heure  \
# 0                 76        Occitanie  Données définitives  2013-01-01  00:00
# 1                 53         Bretagne  Données définitives  2013-01-01  00:00
# 2                 11    Île-de-France  Données définitives  2013-01-01  00:00
# 3                 28        Normandie  Données définitives  2013-01-01  00:00
# 4                 32  Hauts-de-France  Données définitives  2013-01-01  00:00
#
#                 Date - Heure  Consommation (MW)  Thermique (MW)  \
# 0  2013-01-01T00:00:00+01:00                NaN             NaN
# 1  2013-01-01T00:00:00+01:00                NaN             NaN
# 2  2013-01-01T00:00:00+01:00                NaN             NaN
# ...

# %%
energie.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2803968 entries, 0 to 2803967
# Data columns (total 32 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Code INSEE région    int64
#  1   Région               str
#  2   Nature               str
#  3   Date                 str
#  4   Heure                str
#  5   Date - Heure         str
#  6   Consommation (MW)    float64
#  7   Thermique (MW)       float64
#  8   Nucléaire (MW)       float64
#  9   Eolien (MW)          object
#  10  Solaire (MW)         float64
#  11  Hydraulique (MW)     float64
#  12  Pompage (MW)         float64
#  13  Bioénergies (MW)     float64
#  14  Ech. physiques (MW)  float64
#  15  Stockage batterie    float64
#  16  Déstockage batterie  float64
#  17  Eolien terrestre     float64
#  18  Eolien offshore      float64
#  19  TCO Thermique (%)    float64
#  20  TCH Thermique (%)    float64
#  21  TCO Nucléaire (%)    float64
#  22  TCH Nucléaire (%)    float64
# ...

# %%
energie.shape
# Out:
# (2803968, 32)

# %%
#Vérification du nombre de ligne NaN dans la colonne
print("le nombre de ligne NA est de ",energie["Consommation (MW)"].isna().sum())
NbrNA = energie["Consommation (MW)"].isna().sum()
print("% de valeur NA dans la colonne :", (NbrNA/energie.shape[0])*100)
# Out:
# le nombre de ligne NA est de  12
# % de valeur NA dans la colonne : 0.0004279649411120241

# %%
energie.loc[energie["Consommation (MW)"].isna()]
# Out:
#     Code INSEE région                      Région               Nature  \
# 0                  76                   Occitanie  Données définitives
# 1                  53                    Bretagne  Données définitives
# 2                  11               Île-de-France  Données définitives
# 3                  28                   Normandie  Données définitives
# 4                  32             Hauts-de-France  Données définitives
# 5                  44                   Grand Est  Données définitives
# 6                  84        Auvergne-Rhône-Alpes  Données définitives
# 7                  27     Bourgogne-Franche-Comté  Données définitives
# 8                  75          Nouvelle-Aquitaine  Données définitives
# 9                  52            Pays de la Loire  Données définitives
# 10                 24         Centre-Val de Loire  Données définitives
# 11                 93  Provence-Alpes-Côte d'Azur  Données définitives
#
# ...

# %%
#Vérification des valeurs maximales et minimales
print("valeur minimale : ",energie["Consommation (MW)"].min())
print("valeur maximale : ",energie["Consommation (MW)"].max())
# Out:
# valeur minimale :  0.0
# valeur maximale :  15338.0
